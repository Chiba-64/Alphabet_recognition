# %%
import torch
from torch import nn
from torchvision import transforms
from PIL import Image
import sys
sys.path.append('/content/drive/MyDrive/[nf2023]文字認識/alphabet_recognition')
import alphabet_predict

# %%
alphabet_predict.picture_predict("/content/drive/MyDrive/[nf2023]文字認識/N/picture/B_L.png", 28, "letters")
# Out:
# 'b'
